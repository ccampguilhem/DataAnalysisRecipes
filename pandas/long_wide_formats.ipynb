# %% [markdown]
# # Wide and long formats with pandas

# %% [markdown]
# ## Get a dataset from internet

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd

# %% [markdown]
# We download a dataset from www.worldometers.info:

# %%
dfs = pd.read_html("http://www.worldometers.info/world-population/population-by-country/")
df_pop = dfs[0]
df_pop.head()
# Out:
#    # Country (or dependency)  Population (2018) Yearly Change  Net Change  \
# 0  1                   China         1415045928        0.39 %     5528531
# 1  2                   India         1354051854        1.11 %    14871727
# 2  3                    U.S.          326766748        0.71 %     2307285
# 3  4               Indonesia          266794980        1.06 %     2803601
# 4  5                  Brazil          210867954        0.75 %     1579676
#
#    Density (P/Km²)  Land Area (Km²)  Migrants (net) Fert. Rate Med. Age  \
# 0              151          9388211       -339690.0        1.6       37
# 1              455          2973190       -515643.0        2.4       27
# 2               36          9147420        900000.0        1.9       38
# 3              147          1811570       -167000.0        2.5       28
# 4               25          8358140          3185.0        1.8       31
#
#   Urban Pop % World Share
# 0        58 %     18.54 %
# 1        32 %     17.74 %
# 2        83 %      4.28 %
# 3        54 %      3.50 %
# 4        84 %      2.76 %

# %% [markdown]
# ## Converting to long format

# %% [markdown]
# This dataframe has a wide format, all information is provided in columns. Sometimes, to process information, it's better to have a long format. In pandas, this is un unpivoting transformation or melting:

# %%
df_pop.melt().head()
# Out:
#   variable value
# 0        #     1
# 1        #     2
# 2        #     3
# 3        #     4
# 4        #     5

# %% [markdown]
# The dataframe is transformed into a two-column dataframe. The first column holds the name of column from previous dataframe, and the second its value.
#
# In our case this is not very convenient. We would like to keep the # and Country (or dependency) as columns. These columns are id columns, and we can tell melt they are:

# %%
df_melted = df_pop.melt(id_vars=["#", "Country (or dependency)"])
df_melted.head()
# Out:
#    # Country (or dependency)           variable       value
# 0  1                   China  Population (2018)  1415045928
# 1  2                   India  Population (2018)  1354051854
# 2  3                    U.S.  Population (2018)   326766748
# 3  4               Indonesia  Population (2018)   266794980
# 4  5                  Brazil  Population (2018)   210867954

# %% [markdown]
# We can have a closer look to France data:

# %%
df_melted[df_melted["Country (or dependency)"] == "France"]
# Out:
#        # Country (or dependency)           variable     value
# 21    22                  France  Population (2018)  65233271
# 254   22                  France      Yearly Change    0.39 %
# 487   22                  France         Net Change    253723
# 720   22                  France    Density (P/Km²)       119
# 953   22                  France    Land Area (Km²)    547557
# 1186  22                  France     Migrants (net)     72344
# 1419  22                  France         Fert. Rate       2.0
# 1652  22                  France           Med. Age        41
# 1885  22                  France        Urban Pop %      80 %
# 2118  22                  France        World Share    0.85 %

# %% [markdown]
# ## Converting back to wide format, step by step

# %% [markdown]
# The reverse operation of melt is pivot. And we can get back to the original form of the dataframe.
# To do so we can start by grouping and aggregating the data. We group by any column that we want to get in our final dataframe:

# %%
df_step1 = df_melted.groupby(['#', 'Country (or dependency)', 'variable']).aggregate("first")
df_step1.head()
# Out:
#                                              value
# # Country (or dependency) variable
# 1 China                   Density (P/Km²)      151
#                           Fert. Rate           1.6
#                           Land Area (Km²)  9388211
#                           Med. Age              37
#                           Migrants (net)   -339690

# %% [markdown]
# We have as a result a multi-index dataframe. We need to unstack the variable index:

# %%
df_step2 = df_step1.unstack("variable")
df_step2.head()
# Out:
#                                     value                                      \
# variable                  Density (P/Km²) Fert. Rate Land Area (Km²) Med. Age
# # Country (or dependency)
# 1 China                               151        1.6         9388211       37
# 2 India                               455        2.4         2973190       27
# 3 U.S.                                 36        1.9         9147420       38
# 4 Indonesia                           147        2.5         1811570       28
# 5 Brazil                               25        1.8         8358140       31
#
#                                                                        \
# variable                  Migrants (net) Net Change Population (2018)
# # Country (or dependency)
# 1 China                          -339690    5528531        1415045928
# 2 India                          -515643   14871727        1354051854
# 3 U.S.                            900000    2307285         326766748
# 4 Indonesia                      -167000    2803601         266794980
# 5 Brazil                            3185    1579676         210867954
#
#
# variable                  Urban Pop % World Share Yearly Change
# # Country (or dependency)
# 1 China                          58 %     18.54 %        0.39 %
# 2 India                          32 %     17.74 %        1.11 %
# 3 U.S.                           83 %      4.28 %        0.71 %
# 4 Indonesia                      54 %      3.50 %        1.06 %
# 5 Brazil                         84 %      2.76 %        0.75 %

# %% [markdown]
# The columns are also stacked in a multi-index, we can get rid off the outer most level:

# %%
df_step3 = df_step2["value"]
df_step3.head()
# Out:
# variable                  Density (P/Km²) Fert. Rate Land Area (Km²) Med. Age  \
# # Country (or dependency)
# 1 China                               151        1.6         9388211       37
# 2 India                               455        2.4         2973190       27
# 3 U.S.                                 36        1.9         9147420       38
# 4 Indonesia                           147        2.5         1811570       28
# 5 Brazil                               25        1.8         8358140       31
#
# variable                  Migrants (net) Net Change Population (2018)  \
# # Country (or dependency)
# 1 China                          -339690    5528531        1415045928
# 2 India                          -515643   14871727        1354051854
# 3 U.S.                            900000    2307285         326766748
# 4 Indonesia                      -167000    2803601         266794980
# 5 Brazil                            3185    1579676         210867954
#
# variable                  Urban Pop % World Share Yearly Change
# # Country (or dependency)
# 1 China                          58 %     18.54 %        0.39 %
# 2 India                          32 %     17.74 %        1.11 %
# 3 U.S.                           83 %      4.28 %        0.71 %
# 4 Indonesia                      54 %      3.50 %        1.06 %
# 5 Brazil                         84 %      2.76 %        0.75 %

# %% [markdown]
# We then have to reset the index so that # and Country (or dependecy) become columns again:

# %%
df_step4 = df_step3.reset_index()
df_step4.head()
# Out:
# variable  # Country (or dependency) Density (P/Km²) Fert. Rate  \
# 0         1                   China             151        1.6
# 1         2                   India             455        2.4
# 2         3                    U.S.              36        1.9
# 3         4               Indonesia             147        2.5
# 4         5                  Brazil              25        1.8
#
# variable Land Area (Km²) Med. Age Migrants (net) Net Change Population (2018)  \
# 0                9388211       37        -339690    5528531        1415045928
# 1                2973190       27        -515643   14871727        1354051854
# 2                9147420       38         900000    2307285         326766748
# 3                1811570       28        -167000    2803601         266794980
# 4                8358140       31           3185    1579676         210867954
#
# variable Urban Pop % World Share Yearly Change
# 0               58 %     18.54 %        0.39 %
# 1               32 %     17.74 %        1.11 %
# 2               83 %      4.28 %        0.71 %
# 3               54 %      3.50 %        1.06 %
# 4               84 %      2.76 %        0.75 %

# %% [markdown]
# If you want to have absolutely the same dataframe as the one downloaded, you have to rename the column index:

# %%
df_step4.columns.name=""
df_step4.head()
# Out:
#    # Country (or dependency) Density (P/Km²) Fert. Rate Land Area (Km²)  \
# 0  1                   China             151        1.6         9388211
# 1  2                   India             455        2.4         2973190
# 2  3                    U.S.              36        1.9         9147420
# 3  4               Indonesia             147        2.5         1811570
# 4  5                  Brazil              25        1.8         8358140
#
#   Med. Age Migrants (net) Net Change Population (2018) Urban Pop %  \
# 0       37        -339690    5528531        1415045928        58 %
# 1       27        -515643   14871727        1354051854        32 %
# 2       38         900000    2307285         326766748        83 %
# 3       28        -167000    2803601         266794980        54 %
# 4       31           3185    1579676         210867954        84 %
#
#   World Share Yearly Change
# 0     18.54 %        0.39 %
# 1     17.74 %        1.11 %
# 2      4.28 %        0.71 %
# 3      3.50 %        1.06 %
# 4      2.76 %        0.75 %

# %% [markdown]
# Here we are !

# %% [markdown]
# ## Converting back to wide format, with a custom cast function

# %% [markdown]
# We can chain all the previous steps into a custom cast function:

# %%
def cast(df, id_vars=None, columns=None, values=None):
    """
    - df: dataframe to be converted from long to wide format
    - id_vars: [list or str] identification columns that are kept as-is when converting to wide format
    - columns: [str] column holding the name of variables that will be converted into columns
    - values: [str] column holding the values of variables
    """
    #Check input errors
    if id_vars is None:
        raise ValueError("No id_vars provided.")
    elif not hasattr(id_vars, "append"):
        id_vars = [id_vars]
    if columns is None:
        columns = df.columns[-2]
    if values is None:
        values = df.columns[-1]
        
    #We only keep columns we are interested in:
    all_columns = id_vars[:]
    all_columns.extend([columns, values])
    output = df[all_columns]
    
    #Group and aggregate
    group_by = id_vars[:]
    group_by.append(columns)
    output = output.groupby(group_by).aggregate("first")
    
    #Unstack variable and value
    output = output.unstack(columns)[values]
    
    #Reset index
    output = output.reset_index()
    
    #Rename column index
    output.columns.name = ""
    
    #End
    return output

# %% [markdown]
# Let's try our function:

# %%
df_wide = cast(df_melted, id_vars=['#', 'Country (or dependency)'], columns="variable", values="value")
df_wide.head()
# Out:
#    # Country (or dependency) Density (P/Km²) Fert. Rate Land Area (Km²)  \
# 0  1                   China             151        1.6         9388211
# 1  2                   India             455        2.4         2973190
# 2  3                    U.S.              36        1.9         9147420
# 3  4               Indonesia             147        2.5         1811570
# 4  5                  Brazil              25        1.8         8358140
#
#   Med. Age Migrants (net) Net Change Population (2018) Urban Pop %  \
# 0       37        -339690    5528531        1415045928        58 %
# 1       27        -515643   14871727        1354051854        32 %
# 2       38         900000    2307285         326766748        83 %
# 3       28        -167000    2803601         266794980        54 %
# 4       31           3185    1579676         210867954        84 %
#
#   World Share Yearly Change
# 0     18.54 %        0.39 %
# 1     17.74 %        1.11 %
# 2      4.28 %        0.71 %
# 3      3.50 %        1.06 %
# 4      2.76 %        0.75 %

# %% [markdown]
# With less parameters:

# %%
df_wide = cast(df_melted, id_vars='Country (or dependency)')
df_wide.head()
# Out:
#   Country (or dependency) Density (P/Km²) Fert. Rate Land Area (Km²) Med. Age  \
# 0             Afghanistan              56        5.3          652860       17
# 1                 Albania             107        1.7           27400       36
# 2                 Algeria              18        3.0         2381740       28
# 3          American Samoa             278       N.A.             200     N.A.
# 4                 Andorra             164       N.A.             470     N.A.
#
#   Migrants (net) Net Change Population (2018) Urban Pop % World Share  \
# 0          89601     843095          36373176        25 %      0.48 %
# 1         -18685       4176           2934363        65 %      0.04 %
# 2         -28654     689912          42008054        72 %      0.55 %
# 3            NaN         38             55679        88 %      0.00 %
# 4            NaN        -12             76953        90 %      0.00 %
#
#   Yearly Change
# 0        2.37 %
# 1        0.14 %
# 2        1.67 %
# 3        0.07 %
# 4       -0.02 %

# %% [markdown]
# ## Another method using pivot_table
#
# In the previous example, we had non-numeric fields in the dataframe. The non-numeric fields prevent from using pivot_table. This method only apply to dataframes with numerical fields. We can try to convert all fields to numeric values:

# %%
def to_numeric(series):
    def to_float_or_none(value):
        try:
            return float(value)
        except ValueError:
            return None
    if series.name.lower() in ["yearly change", "urban pop %", "world share"]:
        output = series.map(lambda x: to_float_or_none(x.rstrip(' %')), na_action='ignore')
    elif series.name.lower() in ["#", "country (or dependency)"]:
        output = series
    else:
        output = series.map(to_float_or_none)
    return output

df_num = df_pop.apply(to_numeric)
df_num.head()
# Out:
#    # Country (or dependency)  Population (2018)  Yearly Change  Net Change  \
# 0  1                   China       1.415046e+09           0.39   5528531.0
# 1  2                   India       1.354052e+09           1.11  14871727.0
# 2  3                    U.S.       3.267667e+08           0.71   2307285.0
# 3  4               Indonesia       2.667950e+08           1.06   2803601.0
# 4  5                  Brazil       2.108680e+08           0.75   1579676.0
#
#    Density (P/Km²)  Land Area (Km²)  Migrants (net)  Fert. Rate  Med. Age  \
# 0            151.0        9388211.0       -339690.0         1.6      37.0
# 1            455.0        2973190.0       -515643.0         2.4      27.0
# 2             36.0        9147420.0        900000.0         1.9      38.0
# 3            147.0        1811570.0       -167000.0         2.5      28.0
# 4             25.0        8358140.0          3185.0         1.8      31.0
#
#    Urban Pop %  World Share
# 0         58.0        18.54
# 1         32.0        17.74
# 2         83.0         4.28
# 3         54.0         3.50
# 4         84.0         2.76

# %% [markdown]
# We can melt the dataframe as previously:

# %%
df_long = df_num.melt(id_vars=["#", "Country (or dependency)"])
df_long.head()
# Out:
#    # Country (or dependency)           variable         value
# 0  1                   China  Population (2018)  1.415046e+09
# 1  2                   India  Population (2018)  1.354052e+09
# 2  3                    U.S.  Population (2018)  3.267667e+08
# 3  4               Indonesia  Population (2018)  2.667950e+08
# 4  5                  Brazil  Population (2018)  2.108680e+08

# %%
df_wide = df_long.pivot_table(index=["#", "Country (or dependency)"], columns="variable", values="value")
df_wide.head()
# Out:
# variable                   Density (P/Km²)  Fert. Rate  Land Area (Km²)  \
# # Country (or dependency)
# 1 China                              151.0         1.6        9388211.0
# 2 India                              455.0         2.4        2973190.0
# 3 U.S.                                36.0         1.9        9147420.0
# 4 Indonesia                          147.0         2.5        1811570.0
# 5 Brazil                              25.0         1.8        8358140.0
#
# variable                   Med. Age  Migrants (net)  Net Change  \
# # Country (or dependency)
# 1 China                        37.0       -339690.0   5528531.0
# 2 India                        27.0       -515643.0  14871727.0
# 3 U.S.                         38.0        900000.0   2307285.0
# 4 Indonesia                    28.0       -167000.0   2803601.0
# 5 Brazil                       31.0          3185.0   1579676.0
#
# variable                   Population (2018)  Urban Pop %  World Share  \
# # Country (or dependency)
# 1 China                         1.415046e+09         58.0        18.54
# 2 India                         1.354052e+09         32.0        17.74
# 3 U.S.                          3.267667e+08         83.0         4.28
# 4 Indonesia                     2.667950e+08         54.0         3.50
# 5 Brazil                        2.108680e+08         84.0         2.76
#
# variable                   Yearly Change
# # Country (or dependency)
# 1 China                             0.39
# 2 India                             1.11
# 3 U.S.                              0.71
# 4 Indonesia                         1.06
# 5 Brazil                            0.75

# %% [markdown]
# We just have to reset index and rename column index:

# %%
df_wide = df_wide.reset_index()
df_wide.columns.name = ""
df_wide.head()
# Out:
#    # Country (or dependency)  Density (P/Km²)  Fert. Rate  Land Area (Km²)  \
# 0  1                   China            151.0         1.6        9388211.0
# 1  2                   India            455.0         2.4        2973190.0
# 2  3                    U.S.             36.0         1.9        9147420.0
# 3  4               Indonesia            147.0         2.5        1811570.0
# 4  5                  Brazil             25.0         1.8        8358140.0
#
#    Med. Age  Migrants (net)  Net Change  Population (2018)  Urban Pop %  \
# 0      37.0       -339690.0   5528531.0       1.415046e+09         58.0
# 1      27.0       -515643.0  14871727.0       1.354052e+09         32.0
# 2      38.0        900000.0   2307285.0       3.267667e+08         83.0
# 3      28.0       -167000.0   2803601.0       2.667950e+08         54.0
# 4      31.0          3185.0   1579676.0       2.108680e+08         84.0
#
#    World Share  Yearly Change
# 0        18.54           0.39
# 1        17.74           1.11
# 2         4.28           0.71
# 3         3.50           1.06
# 4         2.76           0.75

# %% [markdown]
# Without converting input dataframe into numeric, it is possible to pass an aggregate function to pivot_table to do almost the same than our cast function:

# %%
df_wide = df_melted.pivot_table(index=["#", "Country (or dependency)"], 
                                columns="variable", values="value", aggfunc="first")
df_wide.head()
# Out:
# variable                  Density (P/Km²) Fert. Rate Land Area (Km²) Med. Age  \
# # Country (or dependency)
# 1 China                               151        1.6         9388211       37
# 2 India                               455        2.4         2973190       27
# 3 U.S.                                 36        1.9         9147420       38
# 4 Indonesia                           147        2.5         1811570       28
# 5 Brazil                               25        1.8         8358140       31
#
# variable                  Migrants (net) Net Change Population (2018)  \
# # Country (or dependency)
# 1 China                          -339690    5528531        1415045928
# 2 India                          -515643   14871727        1354051854
# 3 U.S.                            900000    2307285         326766748
# 4 Indonesia                      -167000    2803601         266794980
# 5 Brazil                            3185    1579676         210867954
#
# variable                  Urban Pop % World Share Yearly Change
# # Country (or dependency)
# 1 China                          58 %     18.54 %        0.39 %
# 2 India                          32 %     17.74 %        1.11 %
# 3 U.S.                           83 %      4.28 %        0.71 %
# 4 Indonesia                      54 %      3.50 %        1.06 %
# 5 Brazil                         84 %      2.76 %        0.75 %

# %%
df_wide = df_wide.reset_index()
df_wide.columns.name = ""
df_wide.head()
# Out:
#    # Country (or dependency) Density (P/Km²) Fert. Rate Land Area (Km²)  \
# 0  1                   China             151        1.6         9388211
# 1  2                   India             455        2.4         2973190
# 2  3                    U.S.              36        1.9         9147420
# 3  4               Indonesia             147        2.5         1811570
# 4  5                  Brazil              25        1.8         8358140
#
#   Med. Age Migrants (net) Net Change Population (2018) Urban Pop %  \
# 0       37        -339690    5528531        1415045928        58 %
# 1       27        -515643   14871727        1354051854        32 %
# 2       38         900000    2307285         326766748        83 %
# 3       28        -167000    2803601         266794980        54 %
# 4       31           3185    1579676         210867954        84 %
#
#   World Share Yearly Change
# 0     18.54 %        0.39 %
# 1     17.74 %        1.11 %
# 2      4.28 %        0.71 %
# 3      3.50 %        1.06 %
# 4      2.76 %        0.75 %

# %% [markdown]
# Same output again.
